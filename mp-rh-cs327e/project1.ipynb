# %%
# !mysql < /home/jupyter/mp/snippets/sakila/sakila-database.sql

# %%
# !mysql < /home/jupyter/mp/snippets/sakila/sakila-data.sql

# %%
# !mysql sakila -e "show tables"
# Out:
# +----------------------------+
# | Tables_in_sakila           |
# +----------------------------+
# | actor                      |
# | actor_info                 |
# | address                    |
# | category                   |
# | city                       |
# | country                    |
# | customer                   |
# | customer_list              |
# | film                       |
# | film_actor                 |
# | film_category              |
# | film_list                  |
# | film_text                  |
# | inventory                  |
# | language                   |
# | nicer_but_slower_film_list |
# | payment                    |
# | rental                     |
# | sales_by_film_category     |
# | sales_by_store             |
# | staff                      |
# | staff_list                 |
# | store                      |
# +----------------------------+

# %%
# !mysql sakila -e "select count(*) from actor"
# Out:
# +----------+
# | count(*) |
# +----------+
# |      200 |
# +----------+

# %%
# !mysql sakila -e "select count(*) from actor_info"
# Out:
# +----------+
# | count(*) |
# +----------+
# |      200 |
# +----------+

# %%
# !mysql sakila -e "select count(*) from address"
# Out:
# +----------+
# | count(*) |
# +----------+
# |      603 |
# +----------+

# %%
# !mysql sakila -e "select count(*) from category"
# Out:
# +----------+
# | count(*) |
# +----------+
# |       16 |
# +----------+

# %%
# !mysql sakila -e "select count(*) from city"
# Out:
# +----------+
# | count(*) |
# +----------+
# |      600 |
# +----------+

# %%
# !mysql sakila -e "select count(*) from country"
# Out:
# +----------+
# | count(*) |
# +----------+
# |      109 |
# +----------+

# %%
# !mysql sakila -e "select count(*) from customer"
# Out:
# +----------+
# | count(*) |
# +----------+
# |      599 |
# +----------+

# %%
# !mysql sakila -e "select count(*) from customer_list"
# Out:
# +----------+
# | count(*) |
# +----------+
# |      599 |
# +----------+

# %%
# !mysql sakila -e "select count(*) from film"
# Out:
# +----------+
# | count(*) |
# +----------+
# |     1000 |
# +----------+

# %%
# !mysql sakila -e "select count(*) from film_actor"
# Out:
# +----------+
# | count(*) |
# +----------+
# |     5462 |
# +----------+

# %%
# !mysql sakila -e "select count(*) from film_category"
# Out:
# +----------+
# | count(*) |
# +----------+
# |     1000 |
# +----------+

# %%
# !mysql sakila -e "select count(*) from film_list"
# Out:
# +----------+
# | count(*) |
# +----------+
# |      997 |
# +----------+

# %%
# !mysql sakila -e "select count(*) from film_text"
# Out:
# +----------+
# | count(*) |
# +----------+
# |     1000 |
# +----------+

# %%
# !mysql sakila -e "select count(*) from inventory"
# Out:
# +----------+
# | count(*) |
# +----------+
# |     4581 |
# +----------+

# %%
# !mysql sakila -e "select count(*) from language"
# Out:
# +----------+
# | count(*) |
# +----------+
# |        6 |
# +----------+

# %%
# !mysql sakila -e "select count(*) from nicer_but_slower_film_list"
# Out:
# +----------+
# | count(*) |
# +----------+
# |      997 |
# +----------+

# %%
# !mysql sakila -e "select count(*) from payment"
# Out:
# +----------+
# | count(*) |
# +----------+
# |    16049 |
# +----------+

# %%
# !mysql sakila -e "select count(*) from rental"
# Out:
# +----------+
# | count(*) |
# +----------+
# |    16044 |
# +----------+

# %%
# !mysql sakila -e "select count(*) from sales_by_film_category"
# Out:
# +----------+
# | count(*) |
# +----------+
# |       16 |
# +----------+

# %%
# !mysql sakila -e "select count(*) from sales_by_store"
# Out:
# +----------+
# | count(*) |
# +----------+
# |        2 |
# +----------+

# %%
# !mysql sakila -e "select count(*) from staff"
# Out:
# +----------+
# | count(*) |
# +----------+
# |        2 |
# +----------+

# %%
# !mysql sakila -e "select count(*) from staff_list"
# Out:
# +----------+
# | count(*) |
# +----------+
# |        2 |
# +----------+

# %%
# !mysql sakila -e "select count(*) from store"
# Out:
# +----------+
# | count(*) |
# +----------+
# |        2 |
# +----------+

# %%
# !mysql sakila -e "select * from actor limit 5"
# Out:
# +----------+------------+--------------+---------------------+
# | actor_id | first_name | last_name    | last_update         |
# +----------+------------+--------------+---------------------+
# |        1 | PENELOPE   | GUINESS      | 2006-02-15 04:34:33 |
# |        2 | NICK       | WAHLBERG     | 2006-02-15 04:34:33 |
# |        3 | ED         | CHASE        | 2006-02-15 04:34:33 |
# |        4 | JENNIFER   | DAVIS        | 2006-02-15 04:34:33 |
# |        5 | JOHNNY     | LOLLOBRIGIDA | 2006-02-15 04:34:33 |
# +----------+------------+--------------+---------------------+

# %%
# !mysql sakila -e "select * from actor_info limit 5"
# Out:
# +----------+------------+--------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# ...

# %%
# !mysql sakila -e "select * from address limit 5"
# Out:
# +------------+----------------------+----------+----------+---------+-------------+-------------+---------------------------+---------------------+
# | address_id | address              | address2 | district | city_id | postal_code | phone       | location                  | last_update         |
# +------------+----------------------+----------+----------+---------+-------------+-------------+---------------------------+---------------------+
# |          1 | 47 MySakila Drive    | NULL     | Alberta  |     300 |             |             |        >
# 2]c4\�vۍ��H@     | 2014-09-25 22:30:27 |
# |          2 | 28 MySQL Boulevard   | NULL     | QLD      |     576 |             |             |        ��߁$c@N��P"�;�        | 2014-09-25 22:30:09 |
# |          3 | 23 Workhaven Lane    | NULL     | Alberta  |     300 |             | 14033335568 |        ��hc4\��~p��H@       | 2014-09-25 22:30:27 |
# ...

# %%
# !mysql sakila -e "select * from category limit 5"
# Out:
# +-------------+-----------+---------------------+
# | category_id | name      | last_update         |
# +-------------+-----------+---------------------+
# |           1 | Action    | 2006-02-15 04:46:27 |
# |           2 | Animation | 2006-02-15 04:46:27 |
# |           3 | Children  | 2006-02-15 04:46:27 |
# |           4 | Classics  | 2006-02-15 04:46:27 |
# |           5 | Comedy    | 2006-02-15 04:46:27 |
# +-------------+-----------+---------------------+

# %%
# !mysql sakila -e "select * from city limit 5"
# Out:
# +---------+--------------------+------------+---------------------+
# | city_id | city               | country_id | last_update         |
# +---------+--------------------+------------+---------------------+
# |       1 | A Corua (La Corua) |         87 | 2006-02-15 04:45:25 |
# |       2 | Abha               |         82 | 2006-02-15 04:45:25 |
# |       3 | Abu Dhabi          |        101 | 2006-02-15 04:45:25 |
# |       4 | Acua               |         60 | 2006-02-15 04:45:25 |
# |       5 | Adana              |         97 | 2006-02-15 04:45:25 |
# +---------+--------------------+------------+---------------------+

# %%
# !mysql sakila -e "select * from country limit 5"
# Out:
# +------------+----------------+---------------------+
# | country_id | country        | last_update         |
# +------------+----------------+---------------------+
# |          1 | Afghanistan    | 2006-02-15 04:44:00 |
# |          2 | Algeria        | 2006-02-15 04:44:00 |
# |          3 | American Samoa | 2006-02-15 04:44:00 |
# |          4 | Angola         | 2006-02-15 04:44:00 |
# |          5 | Anguilla       | 2006-02-15 04:44:00 |
# +------------+----------------+---------------------+

# %%
# !mysql sakila -e "select * from customer limit 5"
# Out:
# +-------------+----------+------------+-----------+-------------------------------------+------------+--------+---------------------+---------------------+
# | customer_id | store_id | first_name | last_name | email                               | address_id | active | create_date         | last_update         |
# +-------------+----------+------------+-----------+-------------------------------------+------------+--------+---------------------+---------------------+
# |           1 |        1 | MARY       | SMITH     | MARY.SMITH@sakilacustomer.org       |          5 |      1 | 2006-02-14 22:04:36 | 2006-02-15 04:57:20 |
# |           2 |        1 | PATRICIA   | JOHNSON   | PATRICIA.JOHNSON@sakilacustomer.org |          6 |      1 | 2006-02-14 22:04:36 | 2006-02-15 04:57:20 |
# |           3 |        1 | LINDA      | WILLIAMS  | LINDA.WILLIAMS@sakilacustomer.org   |          7 |      1 | 2006-02-14 22:04:36 | 2006-02-15 04:57:20 |
# ...

# %%
# !mysql sakila -e "select * from customer_list limit 5"
# Out:
# +-----+----------------+-----------------------------+----------+--------------+--------+----------------+--------+-----+
# | ID  | name           | address                     | zip code | phone        | city   | country        | notes  | SID |
# +-----+----------------+-----------------------------+----------+--------------+--------+----------------+--------+-----+
# | 218 | VERA MCCOY     | 1168 Najafabad Parkway      | 40301    | 886649065861 | Kabul  | Afghanistan    | active |   1 |
# | 441 | MARIO CHEATHAM | 1924 Shimonoseki Drive      | 52625    | 406784385440 | Batna  | Algeria        | active |   1 |
# |  69 | JUDY GRAY      | 1031 Daugavpils Parkway     | 59025    | 107137400143 | Bchar  | Algeria        | active |   2 |
# | 176 | JUNE CARROLL   | 757 Rustenburg Avenue       | 89668    | 506134035434 | Skikda | Algeria        | active |   1 |
# | 320 | ANTHONY SCHWAB | 1892 Nabereznyje Telny Lane | 28396    | 478229987054 | Tafuna | American Samoa | active |   2 |
# ...

# %%
# !mysql sakila -e "select * from film limit 5"
# Out:
# +---------+------------------+-----------------------------------------------------------------------------------------------------------------------+--------------+-------------+----------------------+-----------------+-------------+--------+------------------+--------+----------------------------------+---------------------+
# | film_id | title            | description                                                                                                           | release_year | language_id | original_language_id | rental_duration | rental_rate | length | replacement_cost | rating | special_features                 | last_update         |
# +---------+------------------+-----------------------------------------------------------------------------------------------------------------------+--------------+-------------+----------------------+-----------------+-------------+--------+------------------+--------+----------------------------------+---------------------+
# ...

# %%
# !mysql sakila -e "select * from film_actor limit 5"
# Out:
# +----------+---------+---------------------+
# | actor_id | film_id | last_update         |
# +----------+---------+---------------------+
# |        1 |       1 | 2006-02-15 05:05:03 |
# |        1 |      23 | 2006-02-15 05:05:03 |
# |        1 |      25 | 2006-02-15 05:05:03 |
# |        1 |     106 | 2006-02-15 05:05:03 |
# |        1 |     140 | 2006-02-15 05:05:03 |
# +----------+---------+---------------------+

# %%
# !mysql sakila -e "select * from film_category limit 5"
# Out:
# +---------+-------------+---------------------+
# | film_id | category_id | last_update         |
# +---------+-------------+---------------------+
# |       1 |           6 | 2006-02-15 05:07:09 |
# |       2 |          11 | 2006-02-15 05:07:09 |
# |       3 |           6 | 2006-02-15 05:07:09 |
# |       4 |          11 | 2006-02-15 05:07:09 |
# |       5 |           8 | 2006-02-15 05:07:09 |
# +---------+-------------+---------------------+

# %%
# !mysql sakila -e "select * from film_list limit 5"
# Out:
# +------+------------------+-----------------------------------------------------------------------------------------------------------------------+-------------+-------+--------+--------+------------------------------------------------------------------------------------------------------------------------------------------------+
# | FID  | title            | description                                                                                                           | category    | price | length | rating | actors                                                                                                                                         |
# ...

# %%
# !mysql sakila -e "select * from actor film_text limit 5"
# Out:
# +----------+------------+--------------+---------------------+
# | actor_id | first_name | last_name    | last_update         |
# +----------+------------+--------------+---------------------+
# |        1 | PENELOPE   | GUINESS      | 2006-02-15 04:34:33 |
# |        2 | NICK       | WAHLBERG     | 2006-02-15 04:34:33 |
# |        3 | ED         | CHASE        | 2006-02-15 04:34:33 |
# |        4 | JENNIFER   | DAVIS        | 2006-02-15 04:34:33 |
# |        5 | JOHNNY     | LOLLOBRIGIDA | 2006-02-15 04:34:33 |
# +----------+------------+--------------+---------------------+

# %%
# !mysql sakila -e "select * from inventory limit 5"
# Out:
# +--------------+---------+----------+---------------------+
# | inventory_id | film_id | store_id | last_update         |
# +--------------+---------+----------+---------------------+
# |            1 |       1 |        1 | 2006-02-15 05:09:17 |
# |            2 |       1 |        1 | 2006-02-15 05:09:17 |
# |            3 |       1 |        1 | 2006-02-15 05:09:17 |
# |            4 |       1 |        1 | 2006-02-15 05:09:17 |
# |            5 |       1 |        2 | 2006-02-15 05:09:17 |
# +--------------+---------+----------+---------------------+

# %%
# !mysql sakila -e "select * from language limit 5"
# Out:
# +-------------+----------+---------------------+
# | language_id | name     | last_update         |
# +-------------+----------+---------------------+
# |           1 | English  | 2006-02-15 05:02:19 |
# |           2 | Italian  | 2006-02-15 05:02:19 |
# |           3 | Japanese | 2006-02-15 05:02:19 |
# |           4 | Mandarin | 2006-02-15 05:02:19 |
# |           5 | French   | 2006-02-15 05:02:19 |
# +-------------+----------+---------------------+

# %%
# !mysql sakila -e "select * from nicer_but_slower_film_list limit 5"
# Out:
# +------+------------------+-----------------------------------------------------------------------------------------------------------------------+-------------+-------+--------+--------+------------------------------------------------------------------------------------------------------------------------------------------------+
# | FID  | title            | description                                                                                                           | category    | price | length | rating | actors                                                                                                                                         |
# ...

# %%
# !mysql sakila -e "select * from payment limit 5"
# Out:
# +------------+-------------+----------+-----------+--------+---------------------+---------------------+
# | payment_id | customer_id | staff_id | rental_id | amount | payment_date        | last_update         |
# +------------+-------------+----------+-----------+--------+---------------------+---------------------+
# |          1 |           1 |        1 |        76 |   2.99 | 2005-05-25 11:30:37 | 2006-02-15 22:12:30 |
# |          2 |           1 |        1 |       573 |   0.99 | 2005-05-28 10:35:23 | 2006-02-15 22:12:30 |
# |          3 |           1 |        1 |      1185 |   5.99 | 2005-06-15 00:54:12 | 2006-02-15 22:12:30 |
# |          4 |           1 |        2 |      1422 |   0.99 | 2005-06-15 18:02:53 | 2006-02-15 22:12:30 |
# |          5 |           1 |        2 |      1476 |   9.99 | 2005-06-15 21:08:46 | 2006-02-15 22:12:30 |
# +------------+-------------+----------+-----------+--------+---------------------+---------------------+

# %%
# !mysql sakila -e "select * from rental limit 5"
# Out:
# +-----------+---------------------+--------------+-------------+---------------------+----------+---------------------+
# | rental_id | rental_date         | inventory_id | customer_id | return_date         | staff_id | last_update         |
# +-----------+---------------------+--------------+-------------+---------------------+----------+---------------------+
# |         1 | 2005-05-24 22:53:30 |          367 |         130 | 2005-05-26 22:04:30 |        1 | 2006-02-15 21:30:53 |
# |         2 | 2005-05-24 22:54:33 |         1525 |         459 | 2005-05-28 19:40:33 |        1 | 2006-02-15 21:30:53 |
# |         3 | 2005-05-24 23:03:39 |         1711 |         408 | 2005-06-01 22:12:39 |        1 | 2006-02-15 21:30:53 |
# |         4 | 2005-05-24 23:04:41 |         2452 |         333 | 2005-06-03 01:43:41 |        2 | 2006-02-15 21:30:53 |
# |         5 | 2005-05-24 23:05:21 |         2079 |         222 | 2005-06-02 04:33:21 |        1 | 2006-02-15 21:30:53 |
# ...

# %%
# !mysql sakila -e "select * from sales_by_film_category limit 5"
# Out:
# +-----------+-------------+
# | category  | total_sales |
# +-----------+-------------+
# | Sports    |     5314.21 |
# | Sci-Fi    |     4756.98 |
# | Animation |     4656.30 |
# | Drama     |     4587.39 |
# | Comedy    |     4383.58 |
# +-----------+-------------+

# %%
# !mysql sakila -e "select * from sales_by_store limit 5"
# Out:
# +---------------------+--------------+-------------+
# | store               | manager      | total_sales |
# +---------------------+--------------+-------------+
# | Woodridge,Australia | Jon Stephens |    33726.77 |
# | Lethbridge,Canada   | Mike Hillyer |    33679.79 |
# +---------------------+--------------+-------------+

# %%
# !mysql sakila -e "select * from staff limit 5"

# %%
# !mysql sakila -e "select * from staff_list limit 5"
# Out:
# +----+--------------+----------------------+----------+-------------+------------+-----------+-----+
# | ID | name         | address              | zip code | phone       | city       | country   | SID |
# +----+--------------+----------------------+----------+-------------+------------+-----------+-----+
# |  1 | Mike Hillyer | 23 Workhaven Lane    |          | 14033335568 | Lethbridge | Canada    |   1 |
# |  2 | Jon Stephens | 1411 Lillydale Drive |          | 6172235589  | Woodridge  | Australia |   2 |
# +----+--------------+----------------------+----------+-------------+------------+-----------+-----+

# %%
# !mysql sakila -e "select * from store limit 5"
# Out:
# +----------+------------------+------------+---------------------+
# | store_id | manager_staff_id | address_id | last_update         |
# +----------+------------------+------------+---------------------+
# |        1 |                1 |          1 | 2006-02-15 04:57:12 |
# |        2 |                2 |          2 | 2006-02-15 04:57:12 |
# +----------+------------------+------------+---------------------+

# %%
# this query takes the city table and orders the cities by their country ID instead of city ID
# !mysql sakila -e "select * from city order by country_id"
# Out:
# +---------+----------------------------+------------+---------------------+
# | city_id | city                       | country_id | last_update         |
# +---------+----------------------------+------------+---------------------+
# |     251 | Kabul                      |          1 | 2006-02-15 04:45:25 |
# |      59 | Batna                      |          2 | 2006-02-15 04:45:25 |
# |      63 | Bchar                      |          2 | 2006-02-15 04:45:25 |
# |     483 | Skikda                     |          2 | 2006-02-15 04:45:25 |
# |     516 | Tafuna                     |          3 | 2006-02-15 04:45:25 |
# |      67 | Benguela                   |          4 | 2006-02-15 04:45:25 |
# |     360 | Namibe                     |          4 | 2006-02-15 04:45:25 |
# |     493 | South Hill                 |          5 | 2006-02-15 04:45:25 |
# |      20 | Almirante Brown            |          6 | 2006-02-15 04:45:25 |
# ...

# %%
# !mysql sakila -e "delete from actor where actor_id = '201'"

# %%
# !mysql sakila -e "select count(*) from actor"
# Out:
# +----------+
# | count(*) |
# +----------+
# |      200 |
# +----------+

# %%
# this query inserts my name (Misty Peng) into the table of actors as the 201st entry
# !mysql sakila -e "insert into actor() values('201', 'MISTY', 'PENG', '2022-02-03 12:55:26')"

# %%
# this query updates "Nick Wahlberg" to "Mark Wahlberg"
# !mysql sakila -e "update actor set first_name = 'MARK' where actor_id = 2"
# !mysql sakila -e "select * from actor limit 3"
# Out:
# +----------+------------+-----------+---------------------+
# | actor_id | first_name | last_name | last_update         |
# +----------+------------+-----------+---------------------+
# |        1 | PENELOPE   | GUINESS   | 2006-02-15 04:34:33 |
# |        2 | MARK       | WAHLBERG  | 2022-02-03 20:09:41 |
# |        3 | ED         | CHASE     | 2006-02-15 04:34:33 |
# +----------+------------+-----------+---------------------+

# %%
# delete every film category with a category ID of 6
# !mysql sakila -e "delete from film_category where category_id = 6"
# !mysql sakila -e "select * from film_category"
# Out:
# +---------+-------------+---------------------+
# | film_id | category_id | last_update         |
# +---------+-------------+---------------------+
# |       2 |          11 | 2006-02-15 05:07:09 |
# |       4 |          11 | 2006-02-15 05:07:09 |
# |       5 |           8 | 2006-02-15 05:07:09 |
# |       6 |           9 | 2006-02-15 05:07:09 |
# |       7 |           5 | 2006-02-15 05:07:09 |
# |       8 |          11 | 2006-02-15 05:07:09 |
# |       9 |          11 | 2006-02-15 05:07:09 |
# |      10 |          15 | 2006-02-15 05:07:09 |
# |      11 |           9 | 2006-02-15 05:07:09 |
# |      12 |          12 | 2006-02-15 05:07:09 |
# |      13 |          11 | 2006-02-15 05:07:09 |
# |      14 |           4 | 2006-02-15 05:07:09 |
# |      15 |           9 | 2006-02-15 05:07:09 |
# |      16 |           9 | 2006-02-15 05:07:09 |
# |      17 |          12 | 2006-02-15 05:07:09 |
# |      18 |           2 | 2006-02-15 05:07:09 |
# |      19 |           1 | 2006-02-15 05:07:09 |
# ...
